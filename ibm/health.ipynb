# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
df = pd.read_csv('./Student Mental health.csv')
df.shape
# Out:
# (101, 11)

# %%
df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['Timestamp','Did you seek any specialist for a treatment?'],axis=1,inplace=True)
df
# Out:
#     Choose your gender   Age What is your course? Your current year of Study  \
# 0               Female  18.0          Engineering                     year 1
# 1                 Male  21.0    Islamic education                     year 2
# 2                 Male  19.0                  BIT                     Year 1
# 3               Female  22.0                 Laws                     year 3
# 4                 Male  23.0         Mathemathics                     year 4
# ..                 ...   ...                  ...                        ...
# 96              Female  21.0                  BCS                     year 1
# 97                Male  18.0          Engineering                     Year 2
# 98              Female  19.0             Nursing                      Year 3
# 99              Female  23.0     Pendidikan Islam                     year 4
# 100               Male  20.0   Biomedical science                     Year 2
#
# ...

# %%
for i in df.columns:
    print(i)
    df[i].value_counts().plot.bar()
    plt.show()
# Out:
# Choose your gender
# Age
# What is your course?
# Your current year of Study
# What is your CGPA?
# Marital status
# Do you have Depression?
# Do you have Anxiety?
# Do you have Panic attack?

# %%
df['Choose your gender'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
df['Do you have Depression?'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?'],
#       dtype='object')

# %%
df.columns = ['gender', 'age', 'course','year','cgpa','married','depression','anxiety','panic_attack']

# %%
df
# Out:
#      gender   age              course    year         cgpa married depression  \
# 0    Female  18.0         Engineering  year 1  3.00 - 3.49      No        Yes
# 1      Male  21.0   Islamic education  year 2  3.00 - 3.49      No         No
# 2      Male  19.0                 BIT  Year 1  3.00 - 3.49      No        Yes
# 3    Female  22.0                Laws  year 3  3.00 - 3.49     Yes        Yes
# 4      Male  23.0        Mathemathics  year 4  3.00 - 3.49      No         No
# ..      ...   ...                 ...     ...          ...     ...        ...
# 96   Female  21.0                 BCS  year 1  3.50 - 4.00      No         No
# 97     Male  18.0         Engineering  Year 2  3.00 - 3.49      No        Yes
# 98   Female  19.0            Nursing   Year 3  3.50 - 4.00     Yes        Yes
# 99   Female  23.0    Pendidikan Islam  year 4  3.50 - 4.00      No         No
# 100    Male  20.0  Biomedical science  Year 2  3.00 - 3.49      No         No
#
#     anxiety panic_attack
# ...

# %%
df['age'] = df['age'].fillna(df['age'].mean)

# %%
df.isnull().sum()
# Out:
# gender          0
# age             0
# course          0
# year            0
# cgpa            0
# married         0
# depression      0
# anxiety         0
# panic_attack    0
# dtype: int64

# %%
df['year'] = df['year'].replace(['year 1','year 2','year 3','year 4'], ['Year 1','Year 2','Year 3','Year 4'])
df['year'].value_counts()
# Out:
# Year 1    43
# Year 2    26
# Year 3    24
# Year 4     8
# Name: year, dtype: int64

# %%
df2 = pd.read_csv('./Mental Health Questionnaire 2.0.csv')
df2
# Out:
#             Timestamp                 Email address                Name  \
# 0    09-12-2021 23:54          riyaaditi2@gmail.com         Aditi Harsh
# 1    10-12-2021 08:40     imcrazyashutosh@gmail.com      Ashutosh Kumar
# 2    10-12-2021 21:48  atharv23srivastava@gmail.com  Atharv srivastava
# 3    10-12-2021 21:50        ritulricha22@gmail.com                Rimi
# 4    10-12-2021 21:55          nisha18054@gmail.com          Jaya singh
# ..                ...                           ...                 ...
# 153  15-12-2021 13:18        shwetank1921@gmail.com      Kumar shwetank
# 154  15-12-2021 15:17        shukla.anu23@gmail.com       Anurag Shukla
# 155  15-12-2021 21:52      anshikagrawal1@gmail.com             Anshika
# 156  16-12-2021 09:36   mrubaiskhanji1998@gmail.com    Mohd. Ubais Khan
# 157  01-01-2022 15:15          priyaraz96@gmail.com     Kumari Niharika
#
#                 Gender Are you above 30 years of age? Employment Status  \
# ...

# %%
df2.shape
# Out:
# (158, 32)

# %%
df2.isnull().sum()
# Out:
# Timestamp                                                                                                                0
# Email address                                                                                                            0
# Name                                                                                                                     0
# Gender                                                                                                                   0
# Are you above 30 years of age?                                                                                           0
# Employment Status                                                                                                        0
# City                                                                                                                     0
# How are you feeling today?                                                                                               0
# ...
